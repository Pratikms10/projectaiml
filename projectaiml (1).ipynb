# %%
import pandas as pd

# %%
data =pd.read_csv("/content/adult 3.csv")

# %%
data
# Out:
#        age     workclass  fnlwgt     education  educational-num  \
# 0       25       Private  226802          11th                7
# 1       38       Private   89814       HS-grad                9
# 2       28     Local-gov  336951    Assoc-acdm               12
# 3       44       Private  160323  Some-college               10
# 4       18             ?  103497  Some-college               10
# ...    ...           ...     ...           ...              ...
# 48837   27       Private  257302    Assoc-acdm               12
# 48838   40       Private  154374       HS-grad                9
# 48839   58       Private  151910       HS-grad                9
# 48840   22       Private  201490       HS-grad                9
# 48841   52  Self-emp-inc  287927       HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 0           Never-married  Machine-op-inspct    Own-child  Black    Male
# ...

# %%
data.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
data.head(23)
# Out:
#     age         workclass  fnlwgt     education  educational-num  \
# 0    25           Private  226802          11th                7
# 1    38           Private   89814       HS-grad                9
# 2    28         Local-gov  336951    Assoc-acdm               12
# 3    44           Private  160323  Some-college               10
# 4    18                 ?  103497  Some-college               10
# 5    34           Private  198693          10th                6
# 6    29                 ?  227026       HS-grad                9
# 7    63  Self-emp-not-inc  104626   Prof-school               15
# 8    24           Private  369667  Some-college               10
# 9    55           Private  104996       7th-8th                4
# 10   65           Private  184454       HS-grad                9
# 11   36       Federal-gov  212465     Bachelors               13
# 12   26           Private   82091       HS-grad                9
# ...

# %%
data.tail(56)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 48786   33           Private  182401          10th                6
# 48787   38           Private   32916     Assoc-voc               11
# 48788   50           Private  302372     Bachelors               13
# 48789   45           Private  155093          10th                6
# 48790   32           Private  192965       HS-grad                9
# 48791   39           Private  107302       HS-grad                9
# 48792   25         Local-gov  514716     Bachelors               13
# 48793   20           Private  270436       HS-grad                9
# 48794   46           Private   42972       Masters               14
# 48795   40           Private  142657     Assoc-voc               11
# 48796   66       Federal-gov   47358          10th                6
# 48797   30           Private  176175     Assoc-voc               11
# 48798   36           Private  131459       7th-8th                4
# ...

# %%
data.shape
# Out:
# (48842, 15)

# %%
data.isna()
# Out:
#          age  workclass  fnlwgt  education  educational-num  marital-status  \
# 0      False      False   False      False            False           False
# 1      False      False   False      False            False           False
# 2      False      False   False      False            False           False
# 3      False      False   False      False            False           False
# 4      False      False   False      False            False           False
# ...      ...        ...     ...        ...              ...             ...
# 48837  False      False   False      False            False           False
# 48838  False      False   False      False            False           False
# 48839  False      False   False      False            False           False
# 48840  False      False   False      False            False           False
# 48841  False      False   False      False            False           False
#
# ...

# %%
data.isna().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
print(data.occupation.value_counts())
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
print(data.occupation.value_counts)
# Out:
# <bound method IndexOpsMixin.value_counts of 0        Machine-op-inspct
# 1          Farming-fishing
# 2          Protective-serv
# 3        Machine-op-inspct
# 4                        ?
#                ...
# 48837         Tech-support
# 48838    Machine-op-inspct
# 48839         Adm-clerical
# 48840         Adm-clerical
# 48841      Exec-managerial
# Name: occupation, Length: 48842, dtype: object>

# %%
print(data.gender.value_counts())
# Out:
# gender
# Male      32650
# Female    16192
# Name: count, dtype: int64

# %%
print(data.education.value_counts())
# Out:
# education
# HS-grad         15784
# Some-college    10878
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1812
# Assoc-acdm       1601
# 10th             1389
# 7th-8th           955
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# 5th-6th           509
# 1st-4th           247
# Preschool          83
# Name: count, dtype: int64

# %%
print(data.workclass.value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
print(data['marital-status'].value_counts())
# Out:
# marital-status
# Married-civ-spouse       22379
# Never-married            16117
# Divorced                  6633
# Separated                 1530
# Widowed                   1518
# Married-spouse-absent      628
# Married-AF-spouse           37
# Name: count, dtype: int64

# %%
print(data.workclass.value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
data.occupation.replace({'?':'Others'},inplace=True)
# Out:
# /tmp/ipython-input-18-2426378524.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.occupation.replace({'?':'Others'},inplace=True)

# %%
print(data.occupation.value_counts())
# Out:
# occupation
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# Others               2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: count, dtype: int64

# %%
data.workclass.replace({'?':'Notlisited'},inplace=True)
# Out:
# /tmp/ipython-input-20-3430464335.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.workclass.replace({'?':'Notlisited'},inplace=True)

# %%
print(data.workclass.value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# Notlisited           2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: count, dtype: int64

# %%
data=data[data['workclass']!='Without-pay']
data=data[data['workclass']!='Never-worked']

# %%
print(data.workclass.value_counts())
# Out:
# workclass
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# Notlisited           2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (48811, 15)

# %%
data=data[data['education']!='5th-6th']
data=data[data['education']!='1st-4th']
data=data[data['education']!='Preschool']

# %%
print(data.education.value_counts())
# Out:
# education
# HS-grad         15768
# Some-college    10873
# Bachelors        8025
# Masters          2657
# Assoc-voc        2061
# 11th             1809
# Assoc-acdm       1599
# 10th             1387
# 7th-8th           952
# Prof-school       834
# 9th               756
# 12th              657
# Doctorate         594
# Name: count, dtype: int64

# %%
data.shape
# Out:
# (47972, 15)

# %%
data.drop(columns=['education'],inplace=True)

# %%
data
# Out:
#        age     workclass  fnlwgt  educational-num      marital-status  \
# 0       25       Private  226802                7       Never-married
# 1       38       Private   89814                9  Married-civ-spouse
# 2       28     Local-gov  336951               12  Married-civ-spouse
# 3       44       Private  160323               10  Married-civ-spouse
# 4       18    Notlisited  103497               10       Never-married
# ...    ...           ...     ...              ...                 ...
# 48837   27       Private  257302               12  Married-civ-spouse
# 48838   40       Private  154374                9  Married-civ-spouse
# 48839   58       Private  151910                9             Widowed
# 48840   22       Private  201490                9       Never-married
# 48841   52  Self-emp-inc  287927                9  Married-civ-spouse
#
#               occupation relationship   race  gender  capital-gain  \
# ...

# %%
import matplotlib.pyplot as plt
plt.boxplot(data['capital-gain'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(data['educational-num'])
plt.show()

# %%
import matplotlib.pyplot as plt
plt.boxplot(data['hours-per-week'])
plt.show()

# %%
#outlier
import matplotlib.pyplot as plt
plt.boxplot(data['age'])
plt.show()

# %%
data=data[(data['age']<=57) & (data ['age']>=18)]

# %%
plt.boxplot(data.age)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
data['workclass']=encoder.fit_transform(data['workclass'])
data['marital-status']=encoder.fit_transform(data['marital-status'])
data['occupation']=encoder.fit_transform(data['occupation'])
data['relationship']=encoder.fit_transform(data['relationship'])
data['race']=encoder.fit_transform(data['race'])
data['gender']=encoder.fit_transform(data['gender'])
data['native-country']=encoder.fit_transform(data['native-country'])
data
# Out:
# /tmp/ipython-input-36-4044988273.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['workclass']=encoder.fit_transform(data['workclass'])
# /tmp/ipython-input-36-4044988273.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['marital-status']=encoder.fit_transform(data['marital-status'])
# /tmp/ipython-input-36-4044988273.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
x=data.drop(columns=['income'])
y=data['income']
x
# Out:
#        age  workclass  fnlwgt  educational-num  marital-status  occupation  \
# 0       25          3  226802                7               4           6
# 1       38          3   89814                9               2           4
# 2       28          1  336951               12               2          11
# 3       44          3  160323               10               2           6
# 4       18          2  103497               10               4           8
# ...    ...        ...     ...              ...             ...         ...
# 48836   22          3  310152               10               4          11
# 48837   27          3  257302               12               2          13
# 48838   40          3  154374                9               2           6
# 48840   22          3  201490                9               4           0
# 48841   52          4  287927                9               2           3
#
# ...

# %%
y
# Out:
# 0        <=50K
# 1        <=50K
# 2         >50K
# 3         >50K
# 4        <=50K
#          ...
# 48836    <=50K
# 48837    <=50K
# 48838     >50K
# 48840    <=50K
# 48841     >50K
# Name: income, Length: 42436, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# Apply LabelEncoder to all object (string) columns
for col in x.select_dtypes(include='object').columns:
    le = LabelEncoder()
    x[col] = le.fit_transform(x[col])

# %%
import pandas as pd
print(pd.DataFrame(x).isnull().sum())  # for features
print(pd.Series(y).isnull().sum())     # for target
# Out:
# age                0
# workclass          0
# fnlwgt             0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# dtype: int64
# 0

# %%
import pandas as pd

# Combine x and y to drop rows with any missing values
df = pd.concat([pd.DataFrame(x), pd.Series(y, name='target')], axis=1)
df = df.dropna()

# Separate again
x = df.drop('target', axis=1)
y = df['target']

# %%
import pandas as pd
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy='mean')  # or "median", "most_frequent", etc.
x = imputer.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=23, stratify=y)

# %%
x_train
# Out:
# array([[2.00000e+01, 3.00000e+00, 1.61092e+05, ..., 0.00000e+00,
#         1.40000e+01, 3.90000e+01],
#        [1.90000e+01, 3.00000e+00, 1.87724e+05, ..., 0.00000e+00,
#         2.50000e+01, 3.90000e+01],
#        [2.10000e+01, 3.00000e+00, 1.29172e+05, ..., 0.00000e+00,
#         4.00000e+01, 3.90000e+01],
#        ...,
#        [3.80000e+01, 6.00000e+00, 3.54591e+05, ..., 0.00000e+00,
#         3.80000e+01, 3.90000e+01],
#        [4.70000e+01, 3.00000e+00, 1.28796e+05, ..., 0.00000e+00,
#         4.00000e+01, 3.90000e+01],
#        [2.30000e+01, 3.00000e+00, 3.73550e+05, ..., 0.00000e+00,
#         4.00000e+01, 3.90000e+01]])

# %%
#machine learning algorithm s

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
# input and output training data
predict=knn.predict(x_test)
predict
# predict value
# Out:
# array(['<=50K', '<=50K', '<=50K', ..., '<=50K', '<=50K', '>50K'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,predict)
# Out:
# 0.7761545711592837

# %%
from sklearn.neural_network import MLPClassifier
clf=MLPClassifier(solver='adam',hidden_layer_sizes=(5,2),random_state=2,max_iter=2000)
clf.fit(x_train,y_train)
# input and output training data
predict2=clf.predict(x_test)
predict2
# Out:
# array(['<=50K', '<=50K', '<=50K', ..., '<=50K', '<=50K', '<=50K'],
#       dtype='<U5')

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,predict2)
# Out:
# 0.7616635249764373

# %%
# Convert string labels to numeric (only needs to be done once)
y_train = y_train.replace({'<=50K': 0, '>50K': 1})
y_test = y_test.replace({'<=50K': 0, '>50K': 1})
# Out:
# /tmp/ipython-input-50-530246058.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y_train = y_train.replace({'<=50K': 0, '>50K': 1})
# /tmp/ipython-input-50-530246058.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y_test = y_test.replace({'<=50K': 0, '>50K': 1})

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

# SVR pipeline
pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('svr', SVR())
])

# Fit the model
pipeline.fit(x_train, y_train)

# Predict
predict1 = pipeline.predict(x_test)

# Threshold predictions to get class labels
predict1_class = [1 if y >= 0.5 else 0 for y in predict1]

# Evaluate
accuracy = accuracy_score(y_test, predict1_class)
print("SVR Accuracy (with thresholding):", accuracy)
# Out:
# SVR Accuracy (with thresholding): 0.8520263901979265

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# Make sure target is numeric
y_train_nb = y_train.replace({'<=50K': 0, '>50K': 1})
y_test_nb = y_test.replace({'<=50K': 0, '>50K': 1})

# Create and train Naive Bayes model
nb = GaussianNB()
nb.fit(x_train, y_train_nb)

# Predict and evaluate
predict_nb = nb.predict(x_test)
accuracy_nb = accuracy_score(y_test_nb, predict_nb)
print("Naive Bayes Accuracy:", accuracy_nb)
# Out:
# Naive Bayes Accuracy: 0.7897031102733271

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Make sure target is numeric
y_train_bag = y_train.replace({'<=50K': 0, '>50K': 1})
y_test_bag = y_test.replace({'<=50K': 0, '>50K': 1})

# ✅ Updated: Use estimator=... instead of base_estimator
bagging = BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=100, random_state=42)
bagging.fit(x_train, y_train_bag)

# Predict and evaluate
predict_bag = bagging.predict(x_test)
accuracy_bag = accuracy_score(y_test_bag, predict_bag)
print("Bagging Classifier Accuracy:", accuracy_bag)
# Out:
# Bagging Classifier Accuracy: 0.8581526861451461

# %%
from sklearn.ensemble import AdaBoostClassifier

# Create and train AdaBoost Classifier
adaboost = AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=1), n_estimators=100, random_state=42)
adaboost.fit(x_train, y_train_bag)

# Predict and evaluate
predict_ada = adaboost.predict(x_test)
accuracy_ada = accuracy_score(y_test_bag, predict_ada)
print("AdaBoost Classifier Accuracy:", accuracy_ada)
# Out:
# AdaBoost Classifier Accuracy: 0.8566211121583411

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVR
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# Ensure y is numeric
y_train_mod = y_train.replace({'<=50K': 0, '>50K': 1})
y_test_mod = y_test.replace({'<=50K': 0, '>50K': 1})

# Define models (SVR will be handled slightly differently)
models = {
    "KNN": KNeighborsClassifier(),
    "SVR": SVR(),  # Regression model
    "MLPClassifier": MLPClassifier(max_iter=2000, random_state=42),
    "GaussianNB": GaussianNB(),
    "BaggingClassifier": BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=100, random_state=42),
    "AdaBoostClassifier": AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=1), n_estimators=100, random_state=42)
}

results = {}

for name, model in models.items():
    # SVR needs separate handling since it's a regression model
    if name == "SVR":
        pipe = Pipeline([
            ('scaler', StandardScaler()),
            ('model', model)
        ])
        pipe.fit(x_train, y_train_mod)
        ypred_continuous = pipe.predict(x_test)
        ypred = [1 if y >= 0.5 else 0 for y in ypred_continuous]
    else:
        pipe = Pipeline([
            ('scaler', StandardScaler()),
            ('model', model)
        ])
        pipe.fit(x_train, y_train_mod)
        ypred = pipe.predict(x_test)

    acc = accuracy_score(y_test_mod, ypred)
    results[name] = acc
    print(f"\n{name} Accuracy: {acc:.4f}")
    print(classification_report(y_test_mod, ypred))
# Out:
# KNN Accuracy: 0.8340
#               precision    recall  f1-score   support
#
#            0       0.87      0.91      0.89      6430
#            1       0.68      0.59      0.63      2058
#
#     accuracy                           0.83      8488
#    macro avg       0.78      0.75      0.76      8488
# weighted avg       0.83      0.83      0.83      8488
#
#
# SVR Accuracy: 0.8520
#               precision    recall  f1-score   support
#
#            0       0.87      0.94      0.91      6430
#            1       0.76      0.56      0.65      2058
#
#     accuracy                           0.85      8488
#    macro avg       0.82      0.75      0.78      8488
# weighted avg       0.85      0.85      0.84      8488
#
#
# MLPClassifier Accuracy: 0.8537
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      6430
#            1       0.75      0.60      0.66      2058
#
#     accuracy                           0.85      8488
# ...

# %%
import matplotlib.pyplot as plt

# Sort results by accuracy
sorted_results = dict(sorted(results.items(), key=lambda item: item[1]))

plt.figure(figsize=(10, 6))
plt.barh(list(sorted_results.keys()), list(sorted_results.values()), color='mediumseagreen')
plt.xlabel('Accuracy Score')
plt.title('Model Comparison (Sorted)')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
bars = plt.bar(results.keys(), results.values(), color='steelblue')
plt.ylabel('Accuracy Score')
plt.title('Model Accuracy Comparison')

# Add values on top
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2.0, yval + 0.005, f'{yval:.2f}', ha='center', va='bottom')

plt.xticks(rotation=45)
plt.grid(True, axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import numpy as np

# Sample data (replace with actual metric values for each model)
labels = list(results.keys())
scores = list(results.values())

# Radar requires circular data
angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
scores += scores[:1]
angles += angles[:1]

# Plot
fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.plot(angles, scores, 'o-', linewidth=2)
ax.fill(angles, scores, alpha=0.25)
ax.set_thetagrids(np.degrees(angles[:-1]), labels)
ax.set_title("Model Accuracy Radar Chart")
ax.grid(True)
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

fig, axes = plt.subplots(2, 3, figsize=(15, 10))

for ax, (name, model) in zip(axes.ravel(), models.items()):
    if name == "SVR":
        ypred_continuous = model.predict(x_test)
        ypred = [1 if y >= 0.5 else 0 for y in ypred_continuous]
    else:
        ypred = model.predict(x_test)

    cm = confusion_matrix(y_test_mod, ypred)
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax)
    ax.set_title(f"{name}")
    ax.set_xlabel("Predicted")
    ax.set_ylabel("Actual")

plt.tight_layout()
plt.suptitle("Confusion Matrices by Model", fontsize=16, y=1.02)
plt.show()

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVR
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import BaggingClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
import joblib

# 🔄 Convert target to numeric if not already
y = y.replace({'<=50K': 0, '>50K': 1})

# 🔀 Train-test split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# 🧠 Define models
models = {
    "KNN": KNeighborsClassifier(),
    "SVR": SVR(),  # Regression model - thresholded
    "MLPClassifier": MLPClassifier(max_iter=2000, random_state=42),
    "GaussianNB": GaussianNB(),
    "BaggingClassifier": BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=100, random_state=42),
    "AdaBoostClassifier": AdaBoostClassifier(estimator=DecisionTreeClassifier(max_depth=1), n_estimators=100, random_state=42)
}

results = {}

# 🔁 Train, Predict, Evaluate
for name, model in models.items():
    # Use a pipeline with StandardScaler for consistent scaling
    pipe = Pipeline([
        ('scaler', StandardScaler()),
        ('model', model)
    ])

    # Fit model
    pipe.fit(X_train, y_train)

    # Predict
    if name == "SVR":
        y_pred = pipe.predict(X_test)
        y_pred = [1 if pred >= 0.5 else 0 for pred in y_pred]
    else:
        y_pred = pipe.predict(X_test)

    # Accuracy
    acc = accuracy_score(y_test, y_pred)
    results[name] = acc
    print(f"{name}: {acc:.4f}")

# 🏆 Select and Save the Best Model
best_model_name = max(results, key=results.get)
best_model_pipeline = Pipeline([
    ('scaler', StandardScaler()),
    ('model', models[best_model_name])
])
best_model_pipeline.fit(X_train, y_train)

print(f"\n✅ Best model: {best_model_name} with accuracy {results[best_model_name]:.4f}")

# 💾 Save the best model
joblib.dump(best_model_pipeline, "best_model.pkl")
print("✅ Saved best model as best_model.pkl")
# Out:
# /tmp/ipython-input-60-2186914750.py:14: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   y = y.replace({'<=50K': 0, '>50K': 1})
# KNN: 0.8291
# SVR: 0.8533
# MLPClassifier: 0.8561
# GaussianNB: 0.8076
# BaggingClassifier: 0.8570
# AdaBoostClassifier: 0.8563
#
# ✅ Best model: BaggingClassifier with accuracy 0.8570
# ✅ Saved best model as best_model.pkl

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import joblib
import numpy as np

# --- Apply Custom CSS ---
st.markdown("""
    <style>
    body {
        background-color: #f5f5f5;
        font-family: 'Segoe UI', sans-serif;
    }
    .main {
        background-color: white;
        padding: 2rem;
        border-radius: 10px;
        box-shadow: 0 0 10px rgba(0,0,0,0.1);
    }
    h1, h2, h3 {
        color: #0077b6;
    }
    .stButton>button {
        background-color: #00b4d8;
        color: white;
        font-weight: bold;
        border-radius: 8px;
        padding: 0.5em 1em;
        border: none;
    }
    .stButton>button:hover {
        background-color: #0077b6;
        transition: 0.3s;
    }
    .stSidebar {
        background-color: #e6f2f5;
    }
    .stDownloadButton>button {
        background-color: #2a9d8f;
        color: white;
        font-weight: bold;
        border-radius: 8px;
        border: none;
    }
    </style>
""", unsafe_allow_html=True)

# --- Load Model ---
model = joblib.load("best_model.pkl")

# --- Page Config ---
st.set_page_config(page_title="Employee Salary Predictor", page_icon="💼", layout="centered")

# --- Title ---
st.title("💼 Employee Salary Prediction App")
st.markdown("Use this AI-powered app to predict whether an employee earns **>50K or ≤50K** based on job-related details.")

# --- Sidebar ---
st.sidebar.title("🔧 Input Employee Features")
with st.sidebar.expander("📝 Fill in employee details"):
    age = st.slider("Age", 18, 75, 30)
    education = st.selectbox("Education Level", [
        "Bachelors", "Masters", "PhD", "HS-grad", "Assoc", "Some-college"
    ])
    occupation = st.selectbox("Job Role", [
        "Tech-support", "Craft-repair", "Other-service", "Sales",
        "Exec-managerial", "Prof-specialty", "Handlers-cleaners", "Machine-op-inspct",
        "Adm-clerical", "Farming-fishing", "Transport-moving", "Priv-house-serv",
        "Protective-serv", "Armed-Forces"
    ])
    hours_per_week = st.slider("Hours per week", 1, 100, 40)
    experience = st.slider("Years of Experience", 0, 40, 5)

# --- Input DataFrame ---
input_df = pd.DataFrame({
    'age': [age],
    'education': [education],
    'occupation': [occupation],
    'hours-per-week': [hours_per_week],
    'experience': [experience]
})

# --- Tabbed Layout ---
tab1, tab2, tab3 = st.tabs(["🔍 Predict One", "📂 Predict in Bulk", "📈 Model Info"])

# --- Single Prediction ---
with tab1:
    st.header("🔍 Predict a Single Employee's Salary")
    st.write("### Input Preview")
    st.dataframe(input_df)

    if st.button("🔮 Predict Salary Class"):
        try:
            prediction = model.predict(input_df)[0]
            label = ">50K" if prediction == 1 else "≤50K"
            color = "green" if prediction == 1 else "orange"
            st.markdown(f"<h3 style='color:{color}'>✅ Prediction: {label}</h3>", unsafe_allow_html=True)
        except Exception as e:
            st.error(f"🚨 Error during prediction: {str(e)}")

# --- Batch Prediction ---
with tab2:
    st.header("📂 Upload CSV for Bulk Prediction")
    uploaded_file = st.file_uploader("Upload a CSV file", type="csv")

    if uploaded_file:
        try:
            batch_data = pd.read_csv(uploaded_file)
            st.write("📋 Uploaded Data Preview:")
            st.dataframe(batch_data.head())

            preds = model.predict(batch_data)
            batch_data['PredictedClass'] = np.where(preds == 1, '>50K', '≤50K')

            st.success("✅ Predictions complete!")
            st.dataframe(batch_data.head())

            csv = batch_data.to_csv(index=False).encode('utf-8')
            st.download_button("📥 Download Results", csv, file_name="salary_predictions.csv", mime="text/csv")

        except Exception as e:
            st.error(f"🚨 Error: {str(e)}")

# --- Model Info ---
with tab3:
    st.header("📈 Model & Feature Info")
    st.markdown("""
    - 🤖 **Model**: Trained using advanced classifiers (KNN, SVR, MLP, AdaBoost, etc.)
    - ✅ **Best Model Auto-Selected**
    - 🎯 **Target**: Predict if salary is >50K or ≤50K
    - 📊 **Features Used**:
        - Age
        - Education
        - Occupation
        - Hours per week
        - Experience
    - 🔮 **Next Upgrades**:
        - Feature importance visualization
        - Explainable AI with SHAP
        - Upload custom models for testing
    """)

# --- Footer ---
st.markdown("<hr style='border:1px solid #ccc'>", unsafe_allow_html=True)
st.markdown("💡 Built with ❤️ using Streamlit | Customize it further for your organization.", unsafe_allow_html=True)
# Out:
# Writing app.py

# %%
# !pip install streamlit pyngrok
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 534.2 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 22.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 67.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 8.3 MB/s eta 0:00:00
# ...

# %%
# !ngrok authtoken 300rxunPtYYPcQVEBgUED9KyV6q_bUVjLvPJwzMVP2L9wWAe
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
import os
import threading

def run_streamlit():
  os.system('streamlit run app.py --server.port 8000')

thread= threading.Thread(target=run_streamlit)
thread.start()

# %%
from pyngrok import ngrok
import time

time.sleep(3)

public_url = ngrok.connect(8000, "http")  # ✅ Use protocol as second argument
print("Your Streamlit app is live here:", public_url)
# Out:
# Your Streamlit app is live here: NgrokTunnel: "https://9b909474f61e.ngrok-free.app" -> "http://localhost:8000"
